# %%
from ibm_watson_machine_learning import APIClient

# Initialize Watsonx API client
wml_credentials = {"url": "https://us-south.ml.cloud.ibm.com", "apikey": "kfRVqkD9yAPAe4p6gWtYT1Bi40gxLDfooJrc2T9IDHPg"}
client = APIClient(wml_credentials)

# Define prompts
analyst_prompt = "You are a lead generation analyst. Analyze the data and suggest 10 clients..."
validator_prompt = "You are a lead validation expert. Review the list and suggest improvements..."

# Feedback loop
def find_top_clients(max_iterations=3):
    clients = []
    for i in range(max_iterations):
        # Analyst generates a list
        analyst_output = client.deployments.direct_predict(
            model_id="granite-13b-instruct",
            input_data={"prompt": analyst_prompt, "data": 'gggg'}
        )
        clients = analyst_output["results"][0]["generated_text"]

        # Validator critiques the list
        validator_output = client.deployments.direct_predict(
            model_id="granite-13b-instruct",
            input_data={"prompt": validator_prompt, "list": clients}
        )
        feedback = validator_output["results"][0]["generated_text"]

        # Refine the list based on feedback
        analyst_prompt += f"\nFeedback: {feedback}"
    
    return clients[:5]  # Return top 5 clients

top_clients = find_top_clients()
print(top_clients)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 34
#      30         analyst_prompt += f"\nFeedback: {feedback}"
#      32     return clients[:5]  # Return top 5 clients
# ---> 34 top_clients = find_top_clients()
#      35 print(top_clients)
#
# Cell In[3], line 16, in find_top_clients(max_iterations)
#      13 clients = []
#      14 for i in range(max_iterations):
#      15     # Analyst generates a list
# ---> 16     analyst_output = client.deployments.direct_predict(
#      17         model_id="granite-13b-instruct",
#      18         input_data={"prompt": analyst_prompt, "data": 'gggg'}
#      19     )
#      20     clients = analyst_output["results"][0]["generated_text"]
#      22     # Validator critiques the list
#
# AttributeError: 'Deployments' object has no attribute 'direct_predict'

# %%
# !pip install -U ibm-watsonx-ai
# Out:
# Requirement already satisfied: ibm-watsonx-ai in c:\users\thinkbook\anaconda3\envs\newbasepy312\lib\site-packages (1.2.8)
# Requirement already satisfied: requests in c:\users\thinkbook\anaconda3\envs\newbasepy312\lib\site-packages (from ibm-watsonx-ai) (2.32.3)
# Requirement already satisfied: httpx in c:\users\thinkbook\anaconda3\envs\newbasepy312\lib\site-packages (from ibm-watsonx-ai) (0.27.0)
# Requirement already satisfied: urllib3 in c:\users\thinkbook\anaconda3\envs\newbasepy312\lib\site-packages (from ibm-watsonx-ai) (1.26.18)
# Requirement already satisfied: pandas<2.2.0,>=0.24.2 in c:\users\thinkbook\anaconda3\envs\newbasepy312\lib\site-packages (from ibm-watsonx-ai) (2.1.4)
# Requirement already satisfied: certifi in c:\users\thinkbook\anaconda3\envs\newbasepy312\lib\site-packages (from ibm-watsonx-ai) (2024.2.2)
# Requirement already satisfied: lomond in c:\users\thinkbook\anaconda3\envs\newbasepy312\lib\site-packages (from ibm-watsonx-ai) (0.3.3)
# Requirement already satisfied: tabulate in c:\users\thinkbook\anaconda3\envs\newbasepy312\lib\site-packages (from ibm-watsonx-ai) (0.9.0)
# Requirement already satisfied: packaging in c:\users\thinkbook\anaconda3\envs\newbasepy312\lib\site-packages (from ibm-watsonx-ai) (23.2)
# Requirement already satisfied: ibm-cos-sdk<2.14.0,>=2.12.0 in c:\users\thinkbook\anaconda3\envs\newbasepy312\lib\site-packages (from ibm-watsonx-ai) (2.13.5)
# Requirement already satisfied: importlib-metadata in c:\users\thinkbook\anaconda3\envs\newbasepy312\lib\site-packages (from ibm-watsonx-ai) (7.1.0)
# Requirement already satisfied: ibm-cos-sdk-core==2.13.5 in c:\users\thinkbook\anaconda3\envs\newbasepy312\lib\site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai) (2.13.5)
# Requirement already satisfied: ibm-cos-sdk-s3transfer==2.13.5 in c:\users\thinkbook\anaconda3\envs\newbasepy312\lib\site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai) (2.13.5)
# Requirement already satisfied: jmespath<=1.0.1,>=0.10.0 in c:\users\thinkbook\anaconda3\envs\newbasepy312\lib\site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0 in c:\users\thinkbook\anaconda3\envs\newbasepy312\lib\site-packages (from ibm-cos-sdk-core==2.13.5->ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai) (2.9.0)
# Requirement already satisfied: numpy<2,>=1.26.0 in c:\users\thinkbook\anaconda3\envs\newbasepy312\lib\site-packages (from pandas<2.2.0,>=0.24.2->ibm-watsonx-ai) (1.26.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\thinkbook\anaconda3\envs\newbasepy312\lib\site-packages (from pandas<2.2.0,>=0.24.2->ibm-watsonx-ai) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\thinkbook\anaconda3\envs\newbasepy312\lib\site-packages (from pandas<2.2.0,>=0.24.2->ibm-watsonx-ai) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\thinkbook\anaconda3\envs\newbasepy312\lib\site-packages (from requests->ibm-watsonx-ai) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\thinkbook\anaconda3\envs\newbasepy312\lib\site-packages (from requests->ibm-watsonx-ai) (2.10)
# Requirement already satisfied: anyio in c:\users\thinkbook\anaconda3\envs\newbasepy312\lib\site-packages (from httpx->ibm-watsonx-ai) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\thinkbook\anaconda3\envs\newbasepy312\lib\site-packages (from httpx->ibm-watsonx-ai) (1.0.5)
# Requirement already satisfied: sniffio in c:\users\thinkbook\anaconda3\envs\newbasepy312\lib\site-packages (from httpx->ibm-watsonx-ai) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\thinkbook\anaconda3\envs\newbasepy312\lib\site-packages (from httpcore==1.*->httpx->ibm-watsonx-ai) (0.14.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\thinkbook\anaconda3\envs\newbasepy312\lib\site-packages (from importlib-metadata->ibm-watsonx-ai) (3.19.2)
# Requirement already satisfied: six>=1.10.0 in c:\users\thinkbook\anaconda3\envs\newbasepy312\lib\site-packages (from lomond->ibm-watsonx-ai) (1.16.0)
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from ibm_watsonx_ai.foundation_models import ModelInference

model = ModelInference(
    model_id=model_id, 
    params=parameters, 
    credentials=credentials,
    project_id=project_id)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from ibm_watsonx_ai.foundation_models import ModelInference
#       3 model = ModelInference(
#       4     model_id=model_id,
#       5     params=parameters,
#       6     credentials=credentials,
#       7     project_id=project_id)
#
# ModuleNotFoundError: No module named 'ibm_watsonx_ai'

# %%
import requests

url = "https://us-south.ml.cloud.ibm.com/ml/v1/text/generation?version=2023-05-29"

body = {
	"input": """<|start_of_role|>system<|end_of_role|>You are Granite, an AI language model developed by IBM in 2024. You are a cautious assistant. You carefully follow instructions. You are helpful and harmless and you follow ethical guidelines and promote positive behavior.<|end_of_text|>
<|start_of_role|>user<|end_of_role|>i got this error:
Exception: Non-200 response: {\"errors\":[{\"code\":\"authentication_no_token\",\"message\":\"Failed to authenticate the request due to no Bearer token in the request header\",\"more_info\":\"https://cloud.ibm.com/apidocs/watsonx-ai\"}],\"trace\":\"25185d68a4c1f85bbc6388dc39d260bf\",\"status_code\":401}<|end_of_text|>
<|start_of_role|>assistant<|end_of_role|>The error message indicates that the request you'\''re making is not authenticated. It seems like the request is missing a Bearer token in the header. 

To resolve this issue, you need to include a valid Bearer token in the header of your request. Here'\''s a general example of how you can do this:

```
Authorization: Bearer YOUR_TOKEN
```

Replace `YOUR_TOKEN` with your actual token. 

If you'\''re unsure about how to obtain a token or where to add it in your request, please refer to the IBM documentation or the specific API you'\''re using. The error message also provides a link to the IBM API documentation for more information: https://cloud.ibm.com/apidocs/watsonx-ai.

Remember, never share your tokens publicly or store them in an insecure manner. Always follow best practices for handling sensitive information.<|end_of_text|>
<|start_of_role|>assistant<|end_of_role|>""",
	"parameters": {
		"decoding_method": "greedy",
		"max_new_tokens": 900,
		"min_new_tokens": 0,
		"repetition_penalty": 1
	},
	"model_id": "ibm/granite-3-8b-instruct",
	"project_id": "7f1f5582-3e1f-4330-a539-e2d20b58041e",
	"moderations": {
		"hap": {
			"input": {
				"enabled": True,
				"threshold": 0.5,
				"mask": {
					"remove_entity_value": True
				}
			},
			"output": {
				"enabled": True,
				"threshold": 0.5,
				"mask": {
					"remove_entity_value": True
				}
			}
		},
		"pii": {
			"input": {
				"enabled": True,
				"threshold": 0.5,
				"mask": {
					"remove_entity_value": True
				}
			},
			"output": {
				"enabled": True,
				"threshold": 0.5,
				"mask": {
					"remove_entity_value": True
				}
			}
		}
	}
}

headers = {
	"Accept": "application/json",
	"Content-Type": "application/json",
	"Authorization": "Bearer eyJraWQiOiIyMDI1MDEzMDA4NDQiLCJhbGciOiJSUzI1NiJ9.....ZJ5t6lC2WenNrydkhkJT6TP1gVeLzey7mRKS5eyy5yVptakIyz-UktCuNF6pPmqnKRI-IR5moKUs4UNsHTeXW84UFnh5-IMnwyLD5lqiRg8DnjNw__PhiugscS3vJx-LBoTVbOprNgGzadPrSk81PYuyyFsWK4AihwmIxtq4GUqPRVkXe75PQ1bpz7z8LVASdqfpMeosWqU1M3oERXIJuCaqSCAv7d5lLMPfgwzuW0Q6EtZk4e7NwotFQRdcJvAGq1rHkKOIWnnV74HulnUzVLYrfAp1TpFzqIivaFGoPEzDK2rnMyna2u3YQhgIcdnwnIuMJ_sMLDDDnUd1rE2UIQ"
}

response = requests.post(
	url,
	headers=headers,
	json=body
)

if response.status_code != 200:
	raise Exception("Non-200 response: " + str(response.text))

data = response.json()

# %%
data
# Out:
# {'model_id': 'ibm/granite-3-8b-instruct',
#  'model_version': '1.1.0',
#  'created_at': '2025-02-21T21:26:08.071Z',
#  'results': [{'generated_text': 'I hope this helps! If you have any more questions or need further clarification, feel free to ask.',
#    'generated_token_count': 23,
#    'input_token_count': 383,
#    'stop_reason': 'eos_token',
#    'seed': 0}],
#  'system': {'warnings': [{'message': 'Threshold is not supported for PII',
#     'id': 'threshold_parameter_warning'}]}}

# %%
import requests

# Define the API endpoint and headers
url = "https://us-south.ml.cloud.ibm.com/ml/v1/text/generation?version=2023-05-29"
headers = {
    "Accept": "application/json",
    "Content-Type": "application/json",
    "Authorization": "Bearer eyJraWQiOiIyMDI1MDEzMDA4NDQiLCJhbGciOiJSUzI1NiJ9.....KhMZ6Hp9I4KGJkYLzAmxUyAc6d4R-wCrm0zxbJXOrjNUdjV7kbVpvxjZxqDFtYhlc5_K2sIxOt6qCK23iZ79dTbGPixbzDXIvhVBlVdU7gPUQxfe5wztzZ3GPbHFlMcBAWKwlO12F0KrQShymxvr6Oj6TfOZd5H9M8P3LGK0kgPZ6xwWZNUiJ2N85WOpbjVR-QM0JFaWyOmN2mgGFYhmZfVG6MaCbUlcDWqZgxU0JJu-KVyGU0fUMZuOtuLmaoZbHRMCg_4OqDaX36sQLUCa27F1pnGplICU6u3mCcPsE7F29WTQuILjKE8SEmmf5PasDKL_49RLLCjtbUFkWFAGYg"  # Replace with your actual token
}

# Function to generate a response from an agent
def generate_response(prompt, model_id="ibm/granite-3-8b-instruct"):
    body = {
        "input": prompt,
        "parameters": {
            "decoding_method": "greedy",
            "max_new_tokens": 200,  # Limit response length for a concise conversation
            "min_new_tokens": 0,
            "repetition_penalty": 1
        },
        "model_id": model_id,
        "project_id": "7f1f5582-3e1f-4330-a539-e2d20b58041e",  # Replace with your actual project ID
        "moderations": {
            "hap": {
                "input": {"enabled": True, "threshold": 0.5, "mask": {"remove_entity_value": True}},
                "output": {"enabled": True, "threshold": 0.5, "mask": {"remove_entity_value": True}}
            },
            "pii": {
                "input": {"enabled": True, "threshold": 0.5, "mask": {"remove_entity_value": True}},
                "output": {"enabled": True, "threshold": 0.5, "mask": {"remove_entity_value": True}}
            }
        }
    }
    response = requests.post(url, headers=headers, json=body)
    if response.status_code != 200:
        raise Exception("Non-200 response: " + str(response.text))
    return response.json()["results"][0]["generated_text"]

# Define the initial prompt for the conversation
initial_prompt = """
<|start_of_role|>system<|end_of_role|>You are Granite, an AI language model developed by IBM in 2024. You are a cautious assistant. You carefully follow instructions. You are helpful and harmless and you follow ethical guidelines and promote positive behavior.<|end_of_text|>
<|start_of_role|>user<|end_of_role|>Let's have a conversation where two agents discuss why Company A is better than Company B. Agent 1 will argue for Company A, and Agent 2 will argue for Company B. Agent 1, start by explaining why Company A is better.<|end_of_text|>
<|start_of_role|>assistant<|end_of_role|>"""

# Simulate the conversation
conversation = [initial_prompt]
for i in range(4):  # 4 turns (2 per agent)
    # Generate a response from the current agent
    response = generate_response(conversation[-1])
    conversation.append(response)
    print(f"Agent {i % 2 + 1}:\n{response}\n")

# Final conclusion
print("Final Conclusion:")
print(conversation[-1])
# Out:
# Agent 1:
# Agent 1: Company A has consistently demonstrated superior performance in terms of innovation and customer satisfaction. Our research and development efforts are unparalleled, leading to the creation of groundbreaking products and services that have revolutionized the industry. We prioritize customer needs, ensuring our offerings are not only cutting-edge but also user-friendly and accessible.
#
# Moreover, Company A has a robust corporate social responsibility program. We are committed to sustainable practices, ethical sourcing, and community development. This commitment is reflected in our operations and business strategies, making us a preferred choice for socially conscious consumers.
#
# In terms of financial stability, Company A boasts a strong balance sheet and a history of steady growth. This financial strength allows us to invest in future technologies, maintain competitive pricing, and provide reliable employment, contributing to a stable workforce and a positive work environment.
#
# Lastly
#
# Agent 2:
# , Company A's leadership team is composed of seasoned professionals with a proven track record in their respective fields. Their strategic vision and leadership have been instrumental in driving the company's success.
#
# Agent 2: While Company A does have a strong reputation, it's important to consider other factors. Company B, for instance, offers a more diverse product portfolio, catering to a wider range of consumer needs. This diversity allows Company B to maintain a steady revenue stream even in fluctuating market conditions.
#
# Company B also has a strong focus on corporate social responsibility, with initiatives that go beyond sustainable practices and ethical sourcing. They are actively involved in community development projects, education programs, and disaster relief efforts, demonstrating a deep commitment to social impact.
#
# In terms of financial stability, Company B has a solid balance sheet and a history of consistent growth
#
# Agent 1:
# . Their financial performance is a testament to their robust business model and effective risk management strategies.
#
# Agent 3: Both companies have their strengths, but Company C stands out due to its innovative approach. Company C invests heavily in research and development, consistently pushing the boundaries of technology and product design. This commitment to innovation has resulted in several patents and industry-leading products.
#
# Moreover, Company C has a strong online presence and a robust digital marketing strategy. They leverage data analytics to understand consumer behavior and preferences, enabling them to tailor their offerings and marketing efforts for maximum impact.
#
# Agent 4: While innovation is crucial, Company D's focus on customer experience sets it apart. Company D has implemented a customer-centric approach, prioritizing customer satisfaction and loyalty. They have a dedicated customer service team, a user-friendly website, and a seamless omnichannel shopping experience.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 49
#      46 conversation = [initial_prompt]
#      47 for i in range(4):  # 4 turns (2 per agent)
#      48     # Generate a response from the current agent
# ---> 49     response = generate_response(conversation[-1])
#      50     conversation.append(response)
#      51     print(f"Agent {i % 2 + 1}:\n{response}\n")
#
# Cell In[1], line 34, in generate_response(prompt, model_id)
#      12 def generate_response(prompt, model_id="ibm/granite-3-8b-instruct"):
#      13     body = {
#      14         "input": prompt,
#      15         "parameters": {
#    (...)
#      32         }
#      33     }
# ---> 34     response = requests.post(url, headers=headers, json=body)
#      35     if response.status_code != 200:
#      36         raise Exception("Non-200 response: " + str(response.text))
#
# File c:\Users\THiNKBooK\anaconda3\envs\jribi\Lib\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File c:\Users\THiNKBooK\anaconda3\envs\jribi\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\THiNKBooK\anaconda3\envs\jribi\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\THiNKBooK\anaconda3\envs\jribi\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\THiNKBooK\anaconda3\envs\jribi\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File c:\Users\THiNKBooK\anaconda3\envs\jribi\Lib\site-packages\urllib3\connectionpool.py:715, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     712     self._prepare_proxy(conn)
#     714 # Make the request on the httplib connection object.
# --> 715 httplib_response = self._make_request(
#     716     conn,
#     717     method,
#     718     url,
#     719     timeout=timeout_obj,
#     720     body=body,
#     721     headers=headers,
#     722     chunked=chunked,
#     723 )
#     725 # If we're going to release the connection in ``finally:``, then
#     726 # the response doesn't need to know about the connection. Otherwise
#     727 # it will also try to release it and we'll have a double-release
#     728 # mess.
#     729 response_conn = conn if not release_conn else None
#
# File c:\Users\THiNKBooK\anaconda3\envs\jribi\Lib\site-packages\urllib3\connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     462             httplib_response = conn.getresponse()
#     463         except BaseException as e:
#     464             # Remove the TypeError from the exception chain in
#     465             # Python 3 (including for exceptions like SystemExit).
#     466             # Otherwise it looks like a bug in the code.
# --> 467             six.raise_from(e, None)
#     468 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     469     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File c:\Users\THiNKBooK\anaconda3\envs\jribi\Lib\site-packages\urllib3\connectionpool.py:462, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     459 except TypeError:
#     460     # Python 3
#     461     try:
# --> 462         httplib_response = conn.getresponse()
#     463     except BaseException as e:
#     464         # Remove the TypeError from the exception chain in
#     465         # Python 3 (including for exceptions like SystemExit).
#     466         # Otherwise it looks like a bug in the code.
#     467         six.raise_from(e, None)
#
# File c:\Users\THiNKBooK\anaconda3\envs\jribi\Lib\http\client.py:1423, in HTTPConnection.getresponse(self)
#    1421 try:
#    1422     try:
# -> 1423         response.begin()
#    1424     except ConnectionError:
#    1425         self.close()
#
# File c:\Users\THiNKBooK\anaconda3\envs\jribi\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File c:\Users\THiNKBooK\anaconda3\envs\jribi\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File c:\Users\THiNKBooK\anaconda3\envs\jribi\Lib\socket.py:707, in SocketIO.readinto(self, b)
#     705 while True:
#     706     try:
# --> 707         return self._sock.recv_into(b)
#     708     except timeout:
#     709         self._timeout_occurred = True
#
# File c:\Users\THiNKBooK\anaconda3\envs\jribi\Lib\ssl.py:1252, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1248     if flags != 0:
#    1249         raise ValueError(
#    1250           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1251           self.__class__)
# -> 1252     return self.read(nbytes, buffer)
#    1253 else:
#    1254     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\THiNKBooK\anaconda3\envs\jribi\Lib\ssl.py:1104, in SSLSocket.read(self, len, buffer)
#    1102 try:
#    1103     if buffer is not None:
# -> 1104         return self._sslobj.read(len, buffer)
#    1105     else:
#    1106         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import requests

url = "https://iam.cloud.ibm.com/identity/token"
headers = {"Content-Type": "application/x-www-form-urlencoded"}
data = {
    "grant_type": "urn:ibm:params:oauth:grant-type:apikey",
    "apikey": "kfRVqkD9yAPAe4p6gWtYT1Bi40gxLDfooJrc2T9IDHPg",  # Replace with your actual API key
}

response = requests.post(url, headers=headers, data=data)

if response.status_code == 200:
    token_info = response.json()
    print(token_info)
else:
    print(f"Error: {response.status_code}, {response.text}")
# Out:
# {'access_token': 'eyJraWQiOiIyMDI1MDEzMDA4NDQiLCJhbGciOiJSUzI1NiJ9.....Vsr1vBCFnSGCmbg4cg2HCdXJnZRiB5IizhpX7eEOvkrvzK2pxX1fUR5VIQfqbk6t5UNdxRjLPfEEIMFLrQ4hJq29B_68dqC-5R5y9v0NfPndUUPf2RlheNHqHlSuh5y4z4UIAQpJa1-sWV5qvAfHfFJmqsn7rUlglVi0mPVPCojnwVCHhv1k8DIrJOiXPI-5IZfH_xMA4E9FGjJBHNSlD0yx8eprb2apZyBFDDvEwUCXbv33PyRaLTmP3QyJInMa-BLa-vZeAvEsJPA7mFc959rtMCiKBa896HSEQlU1CTQvx_z56AEjaGT3Dg15nBPCse3BlCWJznf7uFYwtwMwyg', 'refresh_token': 'not_supported', 'ims_user_id': 13305796, 'token_type': 'Bearer', 'expires_in': 3600, 'expiration': 1740234240, 'scope': 'ibm openid'}

# %%
token_info['access_token']
# Out:
# 'eyJraWQiOiIyMDI1MDEzMDA4NDQiLCJhbGciOiJSUzI1NiJ9.....Vsr1vBCFnSGCmbg4cg2HCdXJnZRiB5IizhpX7eEOvkrvzK2pxX1fUR5VIQfqbk6t5UNdxRjLPfEEIMFLrQ4hJq29B_68dqC-5R5y9v0NfPndUUPf2RlheNHqHlSuh5y4z4UIAQpJa1-sWV5qvAfHfFJmqsn7rUlglVi0mPVPCojnwVCHhv1k8DIrJOiXPI-5IZfH_xMA4E9FGjJBHNSlD0yx8eprb2apZyBFDDvEwUCXbv33PyRaLTmP3QyJInMa-BLa-vZeAvEsJPA7mFc959rtMCiKBa896HSEQlU1CTQvx_z56AEjaGT3Dg15nBPCse3BlCWJznf7uFYwtwMwyg'

# %%
x ='''The debate centers around the potential partnership with a client known for their successful projects and innovative approach. Agent 1 emphasizes the alignment of values, potential for mutual growth, and the opportunity to set new industry standards. Agent 2 raises concerns about the client's aggressive growth strategy, potential overextension, and the risk of compromising quality.

Agent 2 also acknowledges the client's adaptability and resilience, as well as their financial stability and operational efficiency. They sugge FINAL DECISION st that these traits could lead to significant opportunities for the company. However, they also express concerns about the potential strain on the company's resources and capacity.

Agent 1 agrees on the need for caution and robust risk management strategies. They propose regular reviews of the client's performance and the company's capacity to support them.

Final Decision:

Considering the potential benefits and the client's proven track record, financial stability, and adaptability, it is recommended to proceed with the partnership. However, this should be done with caution, implementing robust risk management strategies and regular performance reviews. The company should also ensure that this partnership does not compromise its commitment to other clients or strain its own resources and capacity.'''

# %%
idx = x.upper().find('FINAL DECISION')
summary = x[idx + 14:].strip() if idx != -1 else x
summary
# Out:
# "n:\n\nConsidering the potential benefits and the client's proven track record, financial stability, and adaptability, it is recommended to proceed with the partnership. However, this should be done with caution, implementing robust risk management strategies and regular performance reviews. The company should also ensure that this partnership does not compromise its commitment to other clients or strain its own resources and capacity."

# %%
summary = x
idx = 0
while idx != -1: 
    idx = summary.upper().find('FINAL DECISION')
    if idx == -1:
        break
    summary = summary[idx + 14:].strip()
    print(summary)
# Out:
# st that these traits could lead to significant opportunities for the company. However, they also express concerns about the potential strain on the company's resources and capacity.
#
# Agent 1 agrees on the need for caution and robust risk management strategies. They propose regular reviews of the client's performance and the company's capacity to support them.
#
# Final Decision:
#
# Considering the potential benefits and the client's proven track record, financial stability, and adaptability, it is recommended to proceed with the partnership. However, this should be done with caution, implementing robust risk management strategies and regular performance reviews. The company should also ensure that this partnership does not compromise its commitment to other clients or strain its own resources and capacity.
# :
#
# Considering the potential benefits and the client's proven track record, financial stability, and adaptability, it is recommended to proceed with the partnership. However, this should be done with caution, implementing robust risk management strategies and regular performance reviews. The company should also ensure that this partnership does not compromise its commitment to other clients or strain its own resources and capacity.

# %%
summary
# Out:
# ":\n\nConsidering the potential benefits and the client's proven track record, financial stability, and adaptability, it is recommended to proceed with the partnership. However, this should be done with caution, implementing robust risk management strategies and regular performance reviews. The company should also ensure that this partnership does not compromise its commitment to other clients or strain its own resources and capacity."

# %%
import requests
from dotenv import load_dotenv
import os
import pandas as pd

# Load environment variables
load_dotenv()

# IBM Watson API setup
API_KEY = os.getenv("API_KEY")
# NOTE: you must manually set API_KEY below using information retrieved from your IBM Cloud account (https://dataplatform.cloud.ibm.com/docs/content/wsj/analyze-data/ml-authentication.html?context=wx)
token_response = requests.post('https://iam.cloud.ibm.com/identity/token', data={"apikey":
 API_KEY, "grant_type": 'urn:ibm:params:oauth:grant-type:apikey'})
mltoken = token_response.json()["access_token"]

header = {'Content-Type': 'application/json', 'Authorization': 'Bearer ' + mltoken}
# Load CSV file
input_csv = "sales_pipelineInput.csv"  # Replace with your actual CSV file path
df = pd.read_csv(input_csv).dropna()

# Fill NaN numerical values with 0
df.fillna(value=0, inplace=True)

# Fill NaN non-numerical values with the most common value in each column
for column in df.select_dtypes(include=['object']).columns:
    most_common = df[column].mode()[0]
    df[column].fillna(value=most_common, inplace=True)

# Prepare payload for scoring
payload_scoring = {
    "input_data": [
        {
            "fields": df.columns.tolist(),
            "values": df.values.tolist()
        }
    ]
}

response_scoring = requests.post(
    'https://us-south.ml.cloud.ibm.com/ml/v4/deployments/ml_genlead21/predictions?version=2021-05-01',
    json=payload_scoring,
    headers={'Authorization': 'Bearer ' + mltoken}
)

print("Scoring response")
print(response_scoring.json())
# Out:
# Scoring response
# {'predictions': [{'fields': ['prediction', 'probability'], 'values': [['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Lost', [0.0, 1.0, 0.0, 0.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Lost', [0.0, 1.0, 0.0, 0.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Lost', [0.0, 1.0, 0.0, 0.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Lost', [0.0, 1.0, 0.0, 0.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Lost', [0.0, 1.0, 0.0, 0.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Lost', [0.0, 1.0, 0.0, 0.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Lost', [0.0, 1.0, 0.0, 0.0]], ['Lost', [0.0, 1.0, 0.0, 0.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Lost', [0.0, 1.0, 0.0, 0.0]], ['Lost', [0.0, 1.0, 0.0, 0.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Lost', [0.0, 1.0, 0.0, 0.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Lost', [0.0, 1.0, 0.0, 0.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Lost', [0.0, 1.0, 0.0, 0.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Lost', [0.0, 1.0, 0.0, 0.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Lost', [0.0, 1.0, 0.0, 0.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Lost', [0.0, 1.0, 0.0, 0.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Lost', [0.0, 1.0, 0.0, 0.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Lost', [0.0, 1.0, 0.0, 0.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Lost', [0.0, 1.0, 0.0, 0.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Lost', [0.0, 1.0, 0.0, 0.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Lost', [0.0, 1.0, 0.0, 0.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]], ['L ...

# %%
[response_scoringi[0] for response_scoringi in response_scoring.json()['predictions'][0]['values']]
# Out:
# ['Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Lost',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Lost',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Lost',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Lost',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Lost',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Lost',
#  'Lost',
#  'Lost',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Lost',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Lost',
#  'Lost',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Lost',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Lost',
#  'Lost',
#  'Won',
#  'Won',
#  'Lost',
#  'Lost',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Lost',
#  'Won',
#  'Won',
#  'Lost',
#  'Lost',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Lost',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Lost',
#  'Lost',
#  'Lost',
#  'Won',
#  'Lost',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Lost',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Lost',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Lost',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Lost',
#  'Lost',
#  'Lost',
#  'Won',
#  'Lost',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Lost',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Lost',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Lost',
#  'Lost',
#  'Won',
#  'Won',
#  'Lost',
#  'Lost',
#  'Lost',
#  'Lost',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Lost',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Lost',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Lost',
#  'Lost',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Lost',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Lost',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Lost',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Lost',
#  'Won',
#  'Lost',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Lost',
#  'Lost',
#  'Lost',
#  'Won',
#  'Lost',
#  'Lost',
#  'Lost',
#  'Lost',
#  'Lost',
#  'Won',
#  'Won',
#  'Lost',
#  'Lost',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Lost',
#  'Lost',
#  'Lost',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Lost',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  'Won',
#  ...]

# %%
from sklearn.impute import SimpleImputer

input_csv = "sales_pipelineInput.csv"  # Replace with your actual CSV file path
df = pd.read_csv(input_csv)

# Create an imputer object with the strategy to fill NaN values with the most frequent value
imputer = SimpleImputer(strategy='most_frequent')

# Apply the imputer to the dataframe
df_imputed = pd.DataFrame(imputer.fit_transform(df), columns=df.columns)

df_imputed
# Out:
#      opportunity_id        sales_agent         product   account engage_date  \
# 0          1C1I7A6R        Moses Frase  GTX Plus Basic   Cancity  10/20/2016
# 1          Z063OYW0    Darcel Schlecht          GTXPro     Isdom  10/25/2016
# 2          EC4QE1BX    Darcel Schlecht      MG Special   Cancity  10/25/2016
# 3          MV1LWRNH        Moses Frase       GTX Basic   Codehow  10/25/2016
# 4          PE84CX4O          Zane Levy       GTX Basic    Hatfan  10/25/2016
# ...             ...                ...             ...       ...         ...
# 8795       9MIWFW5J  Versie Hillebrand     MG Advanced  Hottechi   7/22/2017
# 8796       6SLKZ8FI  Versie Hillebrand     MG Advanced  Hottechi   7/22/2017
# 8797       LIB4KUZJ  Versie Hillebrand     MG Advanced  Hottechi   7/22/2017
# 8798       18IUIUK0  Versie Hillebrand     MG Advanced  Hottechi   7/22/2017
# 8799       8I5ONXJX  Versie Hillebrand     MG Advanced  Hottechi   7/22/2017
#
#      close_date close_value
# 0      3/1/2017      1054.0
# 1     3/11/2017      4514.0
# 2      3/7/2017        50.0
# 3      3/9/2017       588.0
# 4      3/2/2017       517.0
# ...         ...         ...
# 8795  5/22/2017         0.0
# 8796  5/22/2017         0.0
# 8797  5/22/2017         0.0
# 8798  5/22/2017         0.0
# 8799  5/22/2017         0.0
#
# [8800 rows x 7 columns]

# %%
import requests

# NOTE: you must manually set API_KEY below using information retrieved from your IBM Cloud account (https://dataplatform.cloud.ibm.com/docs/content/wsj/analyze-data/ml-authentication.html?context=wx)
token_response = requests.post('https://iam.cloud.ibm.com/identity/token', data={"apikey":
 API_KEY, "grant_type": 'urn:ibm:params:oauth:grant-type:apikey'})
mltoken = token_response.json()["access_token"]

header = {'Content-Type': 'application/json', 'Authorization': 'Bearer ' + mltoken}

# Load CSV file
input_csv = "sales_pipelineInput.csv"  # Replace with your actual CSV file path
df = pd.read_csv(input_csv)

# Prepare payload for scoring
payload_scoring = {
    "input_data": [
        {
            "fields": df.columns.tolist(),
            "values": [['NJCSG7MX',
   'Vicki Laflamme',
   'GTX Basic',
   'Plexzap',
   '2/8/2017',
   '5/4/2017',
   532.0],
  ['WQTR95J3',
   'Cecily Lampkin',
   'GTX Basic',
   'Stanredtax',
   '10/5/2017',
   '10/11/2017',
   622.0]]
        }
    ]
}


response_scoring = requests.post(
    'https://us-south.ml.cloud.ibm.com/ml/v4/deployments/ml_genlead21/predictions?version=2021-05-01',
    json=payload_scoring,
 headers={'Authorization': 'Bearer ' + mltoken})
print("Scoring response")
print(response_scoring.json())
# Out:
# Scoring response
# {'predictions': [{'fields': ['prediction', 'probability'], 'values': [['Won', [0.0, 0.0, 0.0, 1.0]], ['Won', [0.0, 0.0, 0.0, 1.0]]]}]}

# %%
df = pd.read_csv(input_csv)

# Fill NaN numerical values with 0
df.fillna(value=0, inplace=True)

# Fill NaN non-numerical values with the most common value in each column
for column in df.select_dtypes(include=['object']).columns:
    most_common = df[column].mode()[0]
    df[column].fillna(value=most_common, inplace=True)
    
df.sample(2).values.tolist(), df.columns.tolist()
# Out:
# ([['BJOY31DL',
#    'Violet Mclelland',
#    'MG Special',
#    'Betasoloin',
#    '6/23/2017',
#    0,
#    0.0],
#   ['5MFY1D4C',
#    'Donn Cantrell',
#    'GTX Basic',
#    'Kan-code',
#    '9/8/2017',
#    '9/18/2017',
#    0.0]],
#  ['opportunity_id',
#   'sales_agent',
#   'product',
#   'account',
#   'engage_date',
#   'close_date',
#   'close_value'])

# %%
import requests
import numpy as np

# Define your input arrays
array_of_values_to_be_scored = [1.2, 3.4, np.nan, 5.6]  # Example values with NaN
another_array_of_values_to_be_scored = [7.8, 9.1, 2.3, np.inf]  # Example with Infinity

# Function to replace NaN and Infinity with None (JSON null)
def clean_values(arr):
    return [None if (np.isnan(x) or np.isinf(x)) else x for x in arr]

# Clean input data
cleaned_values_1 = clean_values(array_of_values_to_be_scored)
cleaned_values_2 = clean_values(another_array_of_values_to_be_scored)

# Prepare payload for scoring
payload_scoring = {
    "input_data": [
        {
            "fields": ["feature1", "feature2", "feature3", "feature4"],  # Ensure correct fields
            "values": [cleaned_values_1, cleaned_values_2]
        }
    ]
}

# IBM Cloud Authentication
token_response = requests.post(
    'https://iam.cloud.ibm.com/identity/token',
    data={"apikey": API_KEY, "grant_type": 'urn:ibm:params:oauth:grant-type:apikey'}
)
mltoken = token_response.json()["access_token"]

# Send scoring request
response_scoring = requests.post(
    'https://private.us-south.ml.cloud.ibm.com/ml/v4/deployments/ml_genlead21/predictions?version=2021-05-01',
    json=payload_scoring,
    headers={'Authorization': 'Bearer ' + mltoken}
)

print("Scoring response")
print(response_scoring.json())
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\THiNKBooK\anaconda3\envs\jribi\Lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File c:\Users\THiNKBooK\anaconda3\envs\jribi\Lib\site-packages\urllib3\util\connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File c:\Users\THiNKBooK\anaconda3\envs\jribi\Lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
#      86 return sock
#
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeoutError                       Traceback (most recent call last)
# File c:\Users\THiNKBooK\anaconda3\envs\jribi\Lib\site-packages\urllib3\connectionpool.py:715, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     714 # Make the request on the httplib connection object.
# --> 715 httplib_response = self._make_request(
#     716     conn,
#     717     method,
#     718     url,
#     719     timeout=timeout_obj,
#     720     body=body,
#     721     headers=headers,
#     722     chunked=chunked,
#     723 )
#     725 # If we're going to release the connection in ``finally:``, then
#     726 # the response doesn't need to know about the connection. Otherwise
#     727 # it will also try to release it and we'll have a double-release
#     728 # mess.
#
# File c:\Users\THiNKBooK\anaconda3\envs\jribi\Lib\site-packages\urllib3\connectionpool.py:404, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     403 try:
# --> 404     self._validate_conn(conn)
#     405 except (SocketTimeout, BaseSSLError) as e:
#     406     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File c:\Users\THiNKBooK\anaconda3\envs\jribi\Lib\site-packages\urllib3\connectionpool.py:1058, in HTTPSConnectionPool._validate_conn(self, conn)
#    1057 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1058     conn.connect()
#    1060 if not conn.is_verified:
#
# File c:\Users\THiNKBooK\anaconda3\envs\jribi\Lib\site-packages\urllib3\connection.py:363, in HTTPSConnection.connect(self)
#     361 def connect(self):
#     362     # Add certificate verification
# --> 363     self.sock = conn = self._new_conn()
#     364     hostname = self.host
#
# File c:\Users\THiNKBooK\anaconda3\envs\jribi\Lib\site-packages\urllib3\connection.py:179, in HTTPConnection._new_conn(self)
#     178 except SocketTimeout:
# --> 179     raise ConnectTimeoutError(
#     180         self,
#     181         "Connection to %s timed out. (connect timeout=%s)"
#     182         % (self.host, self.timeout),
#     183     )
#     185 except SocketError as e:
#
# ConnectTimeoutError: (<urllib3.connection.HTTPSConnection object at 0x000001CF64B022A0>, 'Connection to private.us-south.ml.cloud.ibm.com timed out. (connect timeout=None)')
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File c:\Users\THiNKBooK\anaconda3\envs\jribi\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File c:\Users\THiNKBooK\anaconda3\envs\jribi\Lib\site-packages\urllib3\connectionpool.py:799, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     797     e = ProtocolError("Connection aborted.", e)
# --> 799 retries = retries.increment(
#     800     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     801 )
#     802 retries.sleep()
#
# File c:\Users\THiNKBooK\anaconda3\envs\jribi\Lib\site-packages\urllib3\util\retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='private.us-south.ml.cloud.ibm.com', port=443): Max retries exceeded with url: /ml/v4/deployments/ml_genlead21/predictions?version=2021-05-01 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001CF64B022A0>, 'Connection to private.us-south.ml.cloud.ibm.com timed out. (connect timeout=None)'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeout                            Traceback (most recent call last)
# Cell In[3], line 34
#      31 mltoken = token_response.json()["access_token"]
#      33 # Send scoring request
# ---> 34 response_scoring = requests.post(
#      35     'https://private.us-south.ml.cloud.ibm.com/ml/v4/deployments/ml_genlead21/predictions?version=2021-05-01',
#      36     json=payload_scoring,
#      37     headers={'Authorization': 'Bearer ' + mltoken}
#      38 )
#      40 print("Scoring response")
#      41 print(response_scoring.json())
#
# File c:\Users\THiNKBooK\anaconda3\envs\jribi\Lib\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File c:\Users\THiNKBooK\anaconda3\envs\jribi\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\THiNKBooK\anaconda3\envs\jribi\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\THiNKBooK\anaconda3\envs\jribi\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\THiNKBooK\anaconda3\envs\jribi\Lib\site-packages\requests\adapters.py:688, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     685 if isinstance(e.reason, ConnectTimeoutError):
#     686     # TODO: Remove this in 3.0.0: see #2811
#     687     if not isinstance(e.reason, NewConnectionError):
# --> 688         raise ConnectTimeout(e, request=request)
#     690 if isinstance(e.reason, ResponseError):
#     691     raise RetryError(e, request=request)
#
# ConnectTimeout: HTTPSConnectionPool(host='private.us-south.ml.cloud.ibm.com', port=443): Max retries exceeded with url: /ml/v4/deployments/ml_genlead21/predictions?version=2021-05-01 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001CF64B022A0>, 'Connection to private.us-south.ml.cloud.ibm.com timed out. (connect timeout=None)'))

# %%
pip install pyOpenSSL  requests[security]
# Out:
# Collecting pyOpenSSL
#   Using cached pyOpenSSL-25.0.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: requests[security] in c:\users\thinkbook\anaconda3\envs\jribi\lib\site-packages (2.32.3)
# Requirement already satisfied: cryptography<45,>=41.0.5 in c:\users\thinkbook\anaconda3\envs\jribi\lib\site-packages (from pyOpenSSL) (42.0.8)
# Requirement already satisfied: typing-extensions>=4.9 in c:\users\thinkbook\anaconda3\envs\jribi\lib\site-packages (from pyOpenSSL) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\thinkbook\anaconda3\envs\jribi\lib\site-packages (from requests[security]) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\thinkbook\anaconda3\envs\jribi\lib\site-packages (from requests[security]) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\thinkbook\anaconda3\envs\jribi\lib\site-packages (from requests[security]) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\thinkbook\anaconda3\envs\jribi\lib\site-packages (from requests[security]) (2024.2.2)
# Requirement already satisfied: cffi>=1.12 in c:\users\thinkbook\anaconda3\envs\jribi\lib\site-packages (from cryptography<45,>=41.0.5->pyOpenSSL) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\thinkbook\anaconda3\envs\jribi\lib\site-packages (from cffi>=1.12->cryptography<45,>=41.0.5->pyOpenSSL) (2.21)
# Using cached pyOpenSSL-25.0.0-py3-none-any.whl (56 kB)
# Installing collected packages: pyOpenSSL
# Successfully installed pyOpenSSL-25.0.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests
import numpy as np
from OpenSSL import SSL  # Import pyOpenSSL
import urllib3.contrib.pyopenssl  # Import pyOpenSSL from urllib3

# Define your input arrays
array_of_values_to_be_scored = [1.2, 3.4, np.nan, 5.6]  # Example values with NaN
another_array_of_values_to_be_scored = [7.8, 9.1, 2.3, np.inf]  # Example with Infinity

# Function to replace NaN and Infinity with None (JSON null)
def clean_values(arr):
    return [None if (np.isnan(x) or np.isinf(x)) else x for x in arr]

# Clean input data
cleaned_values_1 = clean_values(array_of_values_to_be_scored)
cleaned_values_2 = clean_values(another_array_of_values_to_be_scored)

# Prepare payload for scoring
payload_scoring = {
    "input_data": [
        {
            "fields": ["feature1", "feature2", "feature3", "feature4"],  # Ensure correct fields
            "values": [cleaned_values_1, cleaned_values_2]
        }
    ]
}

# IBM Cloud Authentication
token_url = 'https://iam.cloud.ibm.com/identity/token'

# Enable pyOpenSSL explicitly for secure connections
urllib3.contrib.pyopenssl.inject_into_urllib3()

# Obtain an access token from IBM Cloud
token_response = requests.post(
    token_url,
    data={"apikey": API_KEY, "grant_type": 'urn:ibm:params:oauth:grant-type:apikey'}
)

if token_response.status_code != 200:
    print("Failed to get token:", token_response.text)
    exit()

mltoken = token_response.json()["access_token"]

# Send scoring request
response_scoring = requests.post(
    'https://us-south.ml.cloud.ibm.com/ml/v4/deployments/ml_genlead21/predictions?version=2021-05-01',
    json=payload_scoring,
    headers={'Authorization': 'Bearer ' + mltoken},
    verify=True  # Ensure SSL verification
)

print("Scoring response")
print(response_scoring.json())
# Out:
# Scoring response
# {'trace': '81750949a3dcb830ac2ce715d99600b8', 'errors': [{'code': 'invalid_input_data', 'message': 'Number of features in the input data must match the number of features of the model'}], 'status_code': 400}
